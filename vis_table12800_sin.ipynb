# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_excel('./table_12800.xls')

times=df["time between each step"]

plt.plot( times[6000:7000]*1000000)
plt.grid()
plt.figure()

deriv=np.diff(times)

plt.plot(deriv[1:6200])

# %%
times[0] * 1000000
# Out:
# 2.3863907544403914e-09

# %%
times[0:5]
# Out:
# 0    2.386391e-15
# 1    3.702771e-08
# 2    1.110831e-07
# 3    1.851386e-07
# 4    2.591940e-07
# Name: time between each step, dtype: float64

# %%
times[1]  * 1000000
# Out:
# 0.037027713516528254

# %%
times[10] * 1000000
# Out:
# 0.7035265132120552

# %%
times
